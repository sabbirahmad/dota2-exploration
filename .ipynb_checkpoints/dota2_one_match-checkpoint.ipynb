# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils import shuffle
from sklearn.cluster import KMeans
sns.set()  # for plot styling
# %matplotlib inline

# %%
cols = ['event',
        'match_id',
        'team_id',
        'player',
        'timestamp',
        'pos_x',
        'pos_y',
       ]

data = pd.read_csv('match_positions_separated.csv', header=None, names=cols)
data = data[data['pos_x'] > 5000]  # this positions less than 5000 have no data

# %%
data['match_id'].unique()
# Out:
# array([2500623971, 2500632973, 2500694760, 2500724300, 2500811393,
#        2500816344, 2500881491, 2500916535, 2501003221, 2501007313])

# %%
data = data[data['match_id'] == 2500623971]

# %%
data.shape
# Out:
# (88133, 7)

# %%
offset = 100
min_pos_x = min(data['pos_x']) - offset
min_pos_y = min(data['pos_y']) - offset

# %%
data['pos_x'] = data['pos_x'] - min_pos_x
data['pos_y'] = data['pos_y'] - min_pos_x

# %%
data.plot.scatter('pos_x', 'pos_y')

# %%
filtered_events = ['DOTA_COMBATLOG_MAKE_DAMAGE',
                   'DOTA_COMBATLOG_GET_DAMAGE',
                   'DOTA_COMBATLOG_KILL',
                   'DOTA_COMBATLOG_DEATH']

data_fl = data[data['event'].isin(filtered_events)]

# %%
data_fl.shape
# Out:
# (53388, 7)

# %%
data.plot.scatter('pos_x', 'pos_y')

# %%
kmeans = KMeans(n_clusters=100).fit(data_fl[['timestamp', 'pos_x', 'pos_y']])

# %%
data_fl.loc[:, 'label'] = kmeans.labels_
cc = pd.DataFrame(kmeans.cluster_centers_, columns=['timestamp', 'pos_x', 'pos_y'])
cc.plot.scatter('pos_x', 'pos_y')
# Out:
# /Users/ahmadsabbir/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/ahmadsabbir/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data_fl.groupby(['label']).size()
# Out:
# label
# 0      468
# 1     1054
# 2      925
# 3     1527
# 4      471
# 5      571
# 6      878
# 7      310
# 8      692
# 9      525
# 10     652
# 11     801
# 12    1051
# 13     655
# 14     198
# 15     244
# 16      94
# 17     448
# 18     522
# 19     277
# 20     522
# 21     455
# 22     838
# 23     266
# 24    1539
# 25     567
# 26    1379
# 27     920
# 28     439
# 29     424
#       ...
# 70     548
# 71     390
# 72     249
# 73     138
# 74     405
# 75     571
# 76     420
# 77     555
# 78     172
# 79     362
# 80      91
# 81    1409
# 82      34
# 83     257
# 84     159
# 85     548
# 86     216
# 87     703
# 88     104
# 89     350
# 90     250
# 91      94
# 92     607
# 93     678
# 94     328
# 95     196
# 96     415
# 97     198
# 98     268
# 99     468
# Length: 100, dtype: int64

# %%
data_fl[data_fl['label']==0]
# Out:
#                             event    match_id  team_id         player  \
# 22557  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        2  heroalchemist
# 22562         DOTA_COMBATLOG_KILL  2500623971        2  heroalchemist
# 22566  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        2  heroalchemist
# 22568  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        2  heroalchemist
# 22570  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        2  heroalchemist
# 22572   DOTA_COMBATLOG_GET_DAMAGE  2500623971        2  heroalchemist
# 22573  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        2  heroalchemist
# 22576  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        2  heroalchemist
# 22580   DOTA_COMBATLOG_GET_DAMAGE  2500623971        2  heroalchemist
# 22582  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        2  heroalchemist
# 22585  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        2  heroalchemist
# 22588  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        2  heroalchemist
# 22591  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        2  heroalchemist
# 22595   DOTA_COMBATLOG_GET_DAMAGE  2500623971        2  heroalchemist
# 22598   DOTA_COMBATLOG_GET_DAMAGE  2500623971        2  heroalchemist
# 22604  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        2  heroalchemist
# 
# 88044       2505  10837.0  13653.0      0
# 88046       2505  10837.0  13653.0      0
# 88047       2505  10837.0  13653.0      0
# 88049       2506  11045.0  13605.0      0
# 88075       2515  11427.0  13731.0      0
# 88078       2515  11427.0  13731.0      0
# 88082       2516  11295.0  13599.0      0
# 88083       2516  11295.0  13599.0      0
# 88086       2516  11295.0  13599.0      0
# 88099       2520  10945.0  14017.0      0
# 88100       2520  10945.0  14017.0      0
# 88101       2520  10945.0  14017.0      0
#
# [468 rows x 8 columns]

# %%
label_0 = data_fl[data_fl['label']==0]

# %%
kmeans_label_0 = KMeans(n_clusters=20).fit(label_0[['timestamp', 'pos_x', 'pos_y']])

label_0.loc[:, 'sub_label'] = kmeans_label_0.labels_

cc = pd.DataFrame(kmeans_label_0.cluster_centers_, columns=['timestamp', 'pos_x', 'pos_y'])
# Out:
# /Users/ahmadsabbir/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
cc.plot.scatter('pos_x', 'pos_y')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
label_0.groupby(['sub_label']).size()
# Out:
# sub_label
# 0      19
# 1      16
# 2     113
# 3      77
# 4       3
# 5      22
# 6      14
# 7      63
# 8       3
# 9      20
# 10     31
# 11      3
# 12     16
# 13      5
# 14     17
# 15      9
# 16      1
# 17     22
# 18      7
# 19      7
# dtype: int64

# %%
label_0[label_0['sub_label']==0]
# Out:
#                             event    match_id  team_id           player  \
# 80516  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        3  herolifestealer
# 80517   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
# 80518  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        3  herolifestealer
# 80519   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
# 80520  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        3  herolifestealer
# 80521   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
# 80522  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        3  herolifestealer
# 80523   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
# 80524  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        3  herolifestealer
# 80525   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
# 80527   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
# 80528   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
# 80529  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        3  herolifestealer
# 80530   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
# 80531  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        3  herolifestealer
# 80532   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
# 80533   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
# 80534   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
# 80536  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        3  herolifestealer
# 80537   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
# 80540  DOTA_COMBATLOG_MAKE_DAMAGE  2500623971        3  herolifestealer
# 80541   DOTA_COMBATLOG_GET_DAMAGE  2500623971        3  herolifestealer
#
#        timestamp    pos_x    pos_y  label  sub_label
# 80516       2504  10724.0  13540.0      0          0
# 80517       2504  10724.0  13540.0      0          0
# 80518       2504  10724.0  13540.0      0          0
# 80519       2504  10724.0  13540.0      0          0
# 80520       2504  10724.0  13540.0      0          0
# 80521       2504  10724.0  13540.0      0          0
# 80522       2504  10724.0  13540.0      0          0
# 80523       2504  10724.0  13540.0      0          0
# 80524       2504  10724.0  13540.0      0          0
# 80525       2504  10724.0  13540.0      0          0
# 80527       2504  10724.0  13540.0      0          0
# 80528       2504  10724.0  13540.0      0          0
# 80529       2504  10724.0  13540.0      0          0
# 80530       2504  10724.0  13540.0      0          0
# 80531       2504  10724.0  13540.0      0          0
# 80532       2504  10724.0  13540.0      0          0
# 80533       2504  10724.0  13540.0      0          0
# 80534       2504  10724.0  13540.0      0          0
# 80536       2504  10724.0  13540.0      0          0
# 80537       2504  10724.0  13540.0      0          0
# 80540       2504  10724.0  13540.0      0          0
# 80541       2504  10724.0  13540.0      0          0

# %%
cc.plot.scatter('timestamp', 0)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
ts = np.array(label_0[['timestamp', 'pos_x', 'pos_y']])

# %%
plt.scatter(ts[])
